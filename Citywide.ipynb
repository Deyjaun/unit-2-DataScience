# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("Citywide_Payroll_Data__Fiscal_Year_.csv")
df.head()
# Out:
# /var/folders/3q/mfr2s3213rs017839mk54wl80000gq/T/ipykernel_4795/2085091616.py:3: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Citywide_Payroll_Data__Fiscal_Year_.csv")
#    Fiscal Year  Payroll Number                Agency Name      Last Name  \
# 0         2023            67.0  ADMIN FOR CHILDREN'S SVCS  ROSS-FIGUEROA
# 1         2023            67.0  ADMIN FOR CHILDREN'S SVCS          ROSSI
# 2         2023            67.0  ADMIN FOR CHILDREN'S SVCS        ROSTANT
# 3         2023            67.0  ADMIN FOR CHILDREN'S SVCS           ROTH
# 4         2023            67.0  ADMIN FOR CHILDREN'S SVCS        ROTONDO
#
#    First Name Mid Init Agency Start Date Work Location Borough  \
# 0       QIANA        L        06/30/1997             MANHATTAN
# 1     SABRINA        E        09/12/2022             MANHATTAN
# 2     CHERRIE        L        06/23/1996                QUEENS
# 3  JACQUELINE      NaN        06/23/1996             MANHATTAN
# 4     RICHARD        R        11/09/2015             MANHATTAN
#
#                             Title Description Leave Status as of June 30  \
# 0                DIRECTOR OF FIELD OPERATIONS                     CEASED
# 1                             AGENCY ATTORNEY                     ACTIVE
# 2                 CHILD AND FAMILY SPECIALIST                     CEASED
# 3  ADMINISTRATIVE DIRECTOR OF SOCIAL SERVICES                     ACTIVE
# 4                         COMPUTER SPECIALIST                     ACTIVE
#
#    Base Salary  Pay Basis  Regular Hours  Regular Gross Paid  OT Hours  \
# 0     102226.0  per Annum            0.0              128.70       0.0
# 1      83618.0  per Annum         1400.0            55890.87     134.5
# 2      92112.0  per Annum            0.0             1032.76       0.0
# 3     159858.0  per Annum         1820.0           159420.04       0.0
# 4     134497.0  per Annum         1820.0           131177.75       0.0
#
#    Total OT Paid  Total Other Pay
# 0           0.00         14569.12
# 1        6253.42            16.50
# 2           0.00             7.32
# 3           0.00             0.00
# 4           0.00          9121.23

# %%
ploty=df.groupby(['Base Salary','Regular Hours']).Age.mean()
ploty.plot(kind= 'bar')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 ploty=df.groupby(['Base Salary','Regular Hours']).Age.mean()
#       2 ploty.plot(kind= 'bar')
#
# File ~/Library/Python/3.10/lib/python/site-packages/pandas/core/groupby/groupby.py:1312, in GroupBy.__getattr__(self, attr)
#    1309 if attr in self.obj:
#    1310     return self[attr]
# -> 1312 raise AttributeError(
#    1313     f"'{type(self).__name__}' object has no attribute '{attr}'"
#    1314 )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'Age'
