# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# # Mark the downers
#
# We will be using this as the markdown block

# %%
import matplotlib.pyplot as plt

y = [1, 2, 3, 4]
x = [2, 50, 9, 10]
plt.plot(x,y)
plt.ylabel("Drip")
plt.xlabel("Money")
plt.title("Is Drip In My Budget")
# Out:
# Text(0.5, 1.0, 'Is Drip In My Budget')

# %%
import matplotlib.pyplot as plt
import numpy as np

Anime = ("Pokemon", "Dragon ball", "Yugioh")
penguin_means = {
    'Anime Hype': (221, 201, 212),
    'Anime Devs': (18, 12, 22),
    'Anime lovers': (99, 56, 87),
}

x = np.arange(len(Anime)) 
width = 0.25
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

for attribute, measurement in penguin_means.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=3)
    multiplier += 1

ax.set_ylabel('Length (mm)')
ax.set_title('Penguin attributes by species')
ax.set_xticks(x + width, Anime)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 250)

plt.show()

# %%
import matplotlib.pyplot as plt

labels = 'Anime', 'Movies', 'TV Shows', 'Cartoons'
sizes = [29, 30, 40, 18]

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x115e3d030>,
# ...
#  [Text(0.783021231727155, 0.7725786372043233, 'Anime'),
#   Text(-0.7830212678941703, 0.7725786005484532, 'Movies'),
#   Text(-0.4980731271100515, -0.9807768145968861, 'TV Shows'),
#   Text(0.9740017147375195, -0.5111953243999517, 'Cartoons')])
